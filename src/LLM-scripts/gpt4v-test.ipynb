# %%
import openai
from openai import OpenAI
import os
import base64
import requests
openai.api_key = os.environ.get("OPENAI_API_KEY")

# %%
# Function to encode the image to base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# Replace 'path_to_your_image.jpg' with the path to your actual image file
frame_0 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_0.jpg")
frame_900 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_900.jpg")
frame_1800 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_1800.jpg")
frame_2700 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_2700.jpg")
frame_3600 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_3600.jpg")
frame_4500 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_4500.jpg")
frame_5400 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_5400.jpg")
frame_6300 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_6300.jpg")
frame_7200 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_7200.jpg")
frame_8100 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_8100.jpg")
frame_9000 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_9000.jpg")
frame_9900 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_9900.jpg")
frame_10800 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_10800.jpg")
frame_11700 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_11700.jpg")
frame_12600 = encode_image("./../../sampleData/sampleFrames/8eBU4QfrFL4/frame_12600.jpg")

# %%
client = OpenAI()
response = client.chat.completions.create(
  model="gpt-4-vision-preview",
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "Given the sequence of frames sampled from a video, first, summarize each frame. Then summarize the video as a whole.",
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{frame_0}",
          },
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "data:image/jpeg;base64," + frame_900,
          },
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "data:image/jpeg;base64," + frame_1800,
          },
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "data:image/jpeg;base64," + frame_2700,
          },
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "data:image/jpeg;base64," + frame_3600,
          },
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "data:image/jpeg;base64," + frame_4500,
          },
        },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_5400,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_6300,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_7200,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_8100,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_9000,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_9900,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_10800,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_11700,
        #   },
        # },
        # {
        #   "type": "image_url",
        #   "image_url": {
        #     "url": "data:image/jpeg;base64," + frame_12600,
        #   },
        # },
      ],
    }
  ],
)
print(response.choices[0])
# Out:
# Choice(finish_reason=None, index=0, message=ChatCompletionMessage(content='Frame 1: There are five images arranged in a collage, each depicting different', role='assistant', function_call=None, tool_calls=None), finish_details={'type': 'max_tokens'})

# %%
images_folder = "./../../sampleData/sampleFrames/8eBU4QfrFL4/"

image_files = [os.path.join(images_folder, filename) for filename in os.listdir(images_folder) if filename.endswith(".jpg")]
content=[]
text_block={
          "type": "text",
          "text": "What are in these images? Is there any difference between them?",
        }
content.append(text_block)
for image_file in image_files:
    with open(image_file, "rb") as f:
        image_data = f.read()
        base64_image = base64.b64encode(image_data).decode("utf-8")
        image_block={ 
            "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}",
              "detail": "low"}}
        content.append(image_block)
messages_ = [
    {
        
        "role": "user",
        "content": content
    }
]
response = client.chat.completions.create(
  model="gpt-4-vision-preview",
  messages=messages_,
  max_tokens=300,
)
print(response.choices[0])
# Out:
# Choice(finish_reason=None, index=0, message=ChatCompletionMessage(content="The images show various stages and elements of what appears to be a food preparation process, specifically for a type of baked item that resembles bread or a bun with a filling inside.\n\n1. The first image shows a plate with baked beans and a sandwich or hot dog with a bun, mustard, and possibly some kind of relish or pickles on top of the sausage.\n\n2. The second, third, and fourth images depict a mixing bowl containing a thick dough or mixture, and from the fourth image, it's evident that this dough has been shaped into elongated forms similar to bread loaves and baked until they have a brown crust.\n\n3. The fifth image reveals that the baked items have a hollow interior, possibly for stuffing with the sausage seen in the first image, making them sort of edible containers or custom buns.\n\n4. The sixth image shows a bowl with a crumbly dry mixture, which could be another ingredient or another stage in th
# ...

# %%
print(response.choices[0].message.content)
# Out:
# The images show various stages and elements of what appears to be a food preparation process, specifically for a type of baked item that resembles bread or a bun with a filling inside.
#
# 1. The first image shows a plate with baked beans and a sandwich or hot dog with a bun, mustard, and possibly some kind of relish or pickles on top of the sausage.
#
# 2. The second, third, and fourth images depict a mixing bowl containing a thick dough or mixture, and from the fourth image, it's evident that this dough has been shaped into elongated forms similar to bread loaves and baked until they have a brown crust.
#
# 3. The fifth image reveals that the baked items have a hollow interior, possibly for stuffing with the sausage seen in the first image, making them sort of edible containers or custom buns.
#
# 4. The sixth image shows a bowl with a crumbly dry mixture, which could be another ingredient or another stage in the preparation of the dough.
#
# ...
